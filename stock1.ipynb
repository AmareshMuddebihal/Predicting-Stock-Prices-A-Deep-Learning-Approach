# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.stattools import pacf
from statsmodels.regression.linear_model import yule_walker
#from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.stattools import pacf
from statsmodels.regression.linear_model import yule_walker
#from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Generate the data
import numpy as np
ar = np.array([1, -0.8, 0.2])
ma = np.array([1])
my_simulation = ArmaProcess(ar, ma).generate_sample(nsample=100)

plt.figure(figsize=[10, 5]); # Set dimensions for figure
plt.plot(my_simulation, linestyle='-', marker='o', color='b')
plt.title("Simulated Process")
plt.show()

# %%
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
plot_acf(my_simulation)

# %%
plot_pacf(my_simulation)
# Out:
# C:\Users\saivi\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
import warnings
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA

mod = sm.tsa.arima.ARIMA(my_simulation, order=(2, 0, 0))
mod_fit = mod.fit()
print(mod_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                 ARIMA(2, 0, 0)   Log Likelihood                -140.741
# Date:                Sun, 18 Dec 2022   AIC                            289.482
# Time:                        14:08:03   BIC                            299.903
# Sample:                             0   HQIC                           293.699
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7234      0.206      3.517      0.000       0.320       1.127
# ar.L1          0.8596      0.107      8.065      0.000       0.651       1.068
# ar.L2         -0.3420      0.096     -3.547      0.000      -0.531      -0.153
# sigma2         0.9696      0.143      6.802      0.000       0.690       1.249
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 0.14
# Prob(Q):                              0.81   Prob(JB):                         0.93
# Heteroskedasticity (H):               1.13   Skew:                            -0.06
# Prob(H) (two-sided):                  0.72   Kurtosis:                         2.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
array = np.random.random(20) #.astype(np.float32
array.reshape((1,20,1))
array
# Out:
# array([0.14186494, 0.35085066, 0.56762039, 0.05775602, 0.39535777,
#        0.84340627, 0.69968641, 0.22432031, 0.4394662 , 0.79298256,
#        0.10548014, 0.95739217, 0.46892252, 0.83534772, 0.43505676,
#        0.30315824, 0.27420454, 0.13071565, 0.31766175, 0.34287451])

# %%
plt.figure(figsize=[10, 5]); # Set dimensions for figure
plt.plot(array, linestyle='-', marker='o', color='b')
plt.show()

# %%
array.reshape((4,5,1))
# Out:
# array([[[0.14186494],
#         [0.35085066],
#         [0.56762039],
#         [0.05775602],
#         [0.39535777]],
#
#        [[0.84340627],
#         [0.69968641],
#         [0.22432031],
#         [0.4394662 ],
#         [0.79298256]],
#
#        [[0.10548014],
#         [0.95739217],
#         [0.46892252],
#         [0.83534772],
#         [0.43505676]],
#
#        [[0.30315824],
#         [0.27420454],
#         [0.13071565],
#         [0.31766175],
#         [0.34287451]]])

# %%
array.reshape((2,5,2))
# Out:
# array([[[0.14186494, 0.35085066],
#         [0.56762039, 0.05775602],
#         [0.39535777, 0.84340627],
#         [0.69968641, 0.22432031],
#         [0.4394662 , 0.79298256]],
#
#        [[0.10548014, 0.95739217],
#         [0.46892252, 0.83534772],
#         [0.43505676, 0.30315824],
#         [0.27420454, 0.13071565],
#         [0.31766175, 0.34287451]]])

# %%
# Example 1
array = np.random.random(20) #.astype(np.float32
array.reshape((1,20,1))

# Example 2
array.reshape((4,5,1))

# Example 3
array.reshape((2,5,2))
# Out:
# array([[[0.83612546, 0.69430979],
#         [0.81033641, 0.58920045],
#         [0.61412388, 0.36391908],
#         [0.21125505, 0.33057927],
#         [0.61616481, 0.33052886]],
#
#        [[0.00347177, 0.55336615],
#         [0.09501536, 0.76870474],
#         [0.02442414, 0.66567554],
#         [0.14597456, 0.99299577],
#         [0.93216454, 0.83746977]]])

# %%
# IF it is image data:
# Create an RGB image that is 3 dimensional arrays of 8-bit unsigned integers.
width = 5
height = 4
RGB = 3
p = width * height * RGB
img_data = np.random.randint(100,high=255, size=p, dtype=np.uint8) # Generate values in (100,255)
img_data = img_data.reshape((height, width, RGB))
img_data
# Out:
# array([[[142, 105, 254],
#         [155, 194, 125],
#         [245, 162, 123],
#         [226, 141, 198],
#         [133, 201, 216]],
#
#        [[232, 208, 176],
#         [151, 102, 208],
#         [214, 174, 147],
#         [202, 122, 211],
#         [144, 183, 124]],
#
#        [[230, 201, 203],
#         [103, 173, 155],
#         [183, 192, 126],
#         [153, 158, 127],
#         [103, 166, 128]],
#
#        [[192, 153, 129],
#         [223, 176, 205],
#         [230, 168, 205],
#         [116, 209, 163],
#         [109, 236, 121]]], dtype=uint8)

# %%
from PIL import Image
img = Image.fromarray( img_data)
img.show()

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\saivi\anaconda3\lib\site-packages (0.1.90)
# Requirement already satisfied: requests>=2.26 in c:\users\saivi\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\saivi\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\saivi\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\saivi\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\saivi\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\saivi\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saivi\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\saivi\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\saivi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\saivi\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\saivi\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saivi\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saivi\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.24)

# %%
# !pip install yahoofinancials
# Out:
# Requirement already satisfied: yahoofinancials in c:\users\saivi\anaconda3\lib\site-packages (1.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\saivi\anaconda3\lib\site-packages (from yahoofinancials) (4.11.1)
# Requirement already satisfied: pytz in c:\users\saivi\anaconda3\lib\site-packages (from yahoofinancials) (2021.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saivi\anaconda3\lib\site-packages (from beautifulsoup4->yahoofinancials) (2.3.1)

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
AMZN = yf.download('AMZN', 
                      start='2013-01-01', 
                      end='2022-10-31', 
                      progress=False)
# AMZN = yf.download('AMZN') for all 
all_data = AMZN[['Adj Close','Open', 'High', 'Low', 'Close', 'Volume']].round(2)
all_data.head(10)
# Out:
#             Adj Close   Open   High    Low  Close    Volume
# Date
# 2013-01-02      12.87  12.80  12.90  12.66  12.87  65420000
# 2013-01-03      12.92  12.86  13.04  12.82  12.92  55018000
# 2013-01-04      12.96  12.88  12.99  12.83  12.96  37484000
# 2013-01-07      13.42  13.15  13.49  13.13  13.42  98200000
# 2013-01-08      13.32  13.35  13.45  13.18  13.32  60214000
# 2013-01-09      13.32  13.41  13.48  13.27  13.32  45312000
# 2013-01-10      13.27  13.43  13.44  13.11  13.27  57268000
# 2013-01-11      13.40  13.26  13.42  13.21  13.40  48266000
# 2013-01-14      13.64  13.40  13.71  13.38  13.64  85500000
# 2013-01-15      13.60  13.53  13.64  13.47  13.60  46538000

# %%
all_data['Adj Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print("There are "+ str(all_data[:'2019'].shape[0]) + " observations in the training data")
print("There are "+ str(all_data['2020':].shape[0]) + " observations in the test data")
# Out:
# There are 1762 observations in the training data
# There are 713 observations in the test data

# %%
def ts_train_test(all_data,time_steps,for_periods):
    '''
    input: 
      data: dataframe with dates and price data
    output:
      X_train, y_train: data from 2013/1/1-2019/12/31
      X_test:  data from 2020 -
      sc:      insantiated MinMaxScaler object fit to the training data
    '''
    # create training and test set
    ts_train = all_data[:'2019'].iloc[:,0:1].values
    ts_test  = all_data['2020':].iloc[:,0:1].values
    ts_train_len = len(ts_train)
    ts_test_len = len(ts_test)

    # create training data of s samples and t time steps
    X_train = []
    y_train = []
    y_train_stacked = []
    for i in range(time_steps,ts_train_len-1): 
        X_train.append(ts_train[i-time_steps:i,0])
        y_train.append(ts_train[i:i+for_periods,0])
    X_train, y_train = np.array(X_train), np.array(y_train)

    # Reshaping X_train for efficient modelling
    X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

    inputs = pd.concat((all_data["Adj Close"][:'2019'], all_data["Adj Close"]['2020':]),axis=0).values
    inputs = inputs[len(inputs)-len(ts_test) - time_steps:]
    inputs = inputs.reshape(-1,1)

    # Preparing X_test
    X_test = []
    for i in range(time_steps,ts_test_len+time_steps-for_periods):
        X_test.append(inputs[i-time_steps:i,0])
        
    X_test = np.array(X_test)
    X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

    return X_train, y_train , X_test

X_train, y_train, X_test = ts_train_test(all_data,5,2)
X_train.shape[0],X_train.shape[1]
# Out:
# (1756, 5)

# %%
# Make the 3-D shape to a data frame so we can see: 
X_train_see = pd.DataFrame(np.reshape(X_train, (X_train.shape[0],X_train.shape[1])))
y_train_see = pd.DataFrame(y_train)
pd.concat([X_train_see,y_train_see],axis=1)
# Out:
#           0      1      2      3      4      0      1
# 0     12.87  12.92  12.96  13.42  13.32  13.32  13.27
# 1     12.92  12.96  13.42  13.32  13.32  13.27  13.40
# 2     12.96  13.42  13.32  13.32  13.27  13.40  13.64
# 3     13.42  13.32  13.32  13.27  13.40  13.64  13.60
# 4     13.32  13.32  13.27  13.40  13.64  13.60  13.45
# ...     ...    ...    ...    ...    ...    ...    ...
# 1751  88.46  89.53  89.20  89.61  89.32  89.65  89.46
# 1752  89.53  89.20  89.61  89.32  89.65  89.46  93.44
# 1753  89.20  89.61  89.32  89.65  89.46  93.44  93.49
# 1754  89.61  89.32  89.65  89.46  93.44  93.49  92.34
# 1755  89.32  89.65  89.46  93.44  93.49  92.34  92.39
#
# [1756 rows x 7 columns]

# %%
# Make the 3-D shape to a data frame so we can see: 
X_test_see = pd.DataFrame(np.reshape(X_test, (X_test.shape[0],X_test.shape[1])))
pd.DataFrame(X_test_see)
# Out:
#           0       1       2       3       4
# 0     89.46   93.44   93.49   92.34   92.39
# 1     93.44   93.49   92.34   92.39   94.90
# 2     93.49   92.34   92.39   94.90   93.75
# 3     92.34   92.39   94.90   93.75   95.14
# 4     92.39   94.90   93.75   95.14   95.34
# ..      ...     ...     ...     ...     ...
# 706  112.53  106.90  113.79  116.36  115.07
# 707  106.90  113.79  116.36  115.07  115.25
# 708  113.79  116.36  115.07  115.25  119.32
# 709  116.36  115.07  115.25  119.32  119.82
# 710  115.07  115.25  119.32  119.82  120.60
#
# [711 rows x 5 columns]

# %%
print("There are " + str(X_train.shape[0]) + " samples in the training data")
print("There are " + str(X_test.shape[0]) + " samples in the test data")
# Out:
# There are 1756 samples in the training data
# There are 711 samples in the test data

# %%
def simple_rnn_model(X_train, y_train, X_test):
    '''
    create single layer rnn model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # create a model
    from keras.models import Sequential
    from keras.layers import Dense, SimpleRNN
    
    my_rnn_model = Sequential()
    my_rnn_model.add(SimpleRNN(32, return_sequences=True))
    #my_rnn_model.add(SimpleRNN(32, return_sequences=True))
    #my_rnn_model.add(SimpleRNN(32, return_sequences=True))
    my_rnn_model.add(SimpleRNN(32))
    my_rnn_model.add(Dense(2)) # The time step of the output

    my_rnn_model.compile(optimizer='rmsprop', loss='mean_squared_error')

    # fit the RNN model
    my_rnn_model.fit(X_train, y_train, epochs=100, batch_size=150, verbose=0)

    # Finalizing predictions
    rnn_predictions = my_rnn_model.predict(X_test)

    return my_rnn_model, rnn_predictions

my_rnn_model, rnn_predictions = simple_rnn_model(X_train, y_train, X_test)
rnn_predictions[1:10]
# Out:
# 23/23 [==============================] - 1s 3ms/step
# array([[43.190544, 43.450687],
#        [43.190544, 43.450687],
#        [43.190544, 43.450687],
#        [43.190548, 43.450687],
#        [43.190548, 43.450687],
#        [43.190544, 43.450687],
#        [43.190544, 43.450687],
#        [43.190544, 43.450687],
#        [43.190544, 43.450687]], dtype=float32)

# %%
def actual_pred_plot(preds):
    actual_pred = pd.DataFrame(columns = ['Adj. Close', 'prediction'])
    actual_pred['Adj. Close'] = all_data.loc['2020':,'Adj Close'][0:len(preds)]
    actual_pred['prediction'] = preds[:,0]

    from keras.metrics import MeanSquaredError
    m = MeanSquaredError()
    m.update_state(np.array(actual_pred['Adj. Close']),np.array(actual_pred['prediction']))
    
    return (m.result().numpy(), actual_pred.plot() )
    
actual_pred_plot(rnn_predictions)
# Out:
# (11148.636, <AxesSubplot:xlabel='Date'>)

# %%
def ts_train_test_normalize(all_data,time_steps,for_periods):
    '''
    input: 
      data: dataframe with dates and price data
    output:
      X_train, y_train: data from 2013/1/1-2019/12/31
      X_test:  data from 2020 -
      sc:      insantiated MinMaxScaler object fit to the training data
    '''
    # create training and test set
    ts_train = all_data[:'2019'].iloc[:,0:1].values
    ts_test  = all_data['2020':].iloc[:,0:1].values
    ts_train_len = len(ts_train)
    ts_test_len = len(ts_test)

    # scale the data
    from sklearn.preprocessing import MinMaxScaler
    sc = MinMaxScaler(feature_range=(0,1))
    ts_train_scaled = sc.fit_transform(ts_train)

    # create training data of s samples and t time steps
    X_train = []
    y_train = []
    y_train_stacked = []
    for i in range(time_steps,ts_train_len-1): 
        X_train.append(ts_train_scaled[i-time_steps:i,0])
        y_train.append(ts_train_scaled[i:i+for_periods,0])
    X_train, y_train = np.array(X_train), np.array(y_train)

    # Reshaping X_train for efficient modelling
    X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

    inputs = pd.concat((all_data["Adj Close"][:'2019'], all_data["Adj Close"]['2020':]),axis=0).values
    inputs = inputs[len(inputs)-len(ts_test) - time_steps:]
    inputs = inputs.reshape(-1,1)
    inputs  = sc.transform(inputs)

    # Preparing X_test
    X_test = []
    for i in range(time_steps,ts_test_len+time_steps-for_periods):
        X_test.append(inputs[i-time_steps:i,0])
        
    X_test = np.array(X_test)
    X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

    return X_train, y_train , X_test, sc

def simple_rnn_model(X_train, y_train, X_test, sc):
    '''
    create single layer rnn model trained on X_train and y_train
    and make predictions on the X_test data
    '''
    # create a model
    from keras.models import Sequential
    from keras.layers import Dense, SimpleRNN
    
    my_rnn_model = Sequential()
    my_rnn_model.add(SimpleRNN(32, return_sequences=True))
    #my_rnn_model.add(SimpleRNN(32, return_sequences=True))
    #my_rnn_model.add(SimpleRNN(32, return_sequences=True))
    my_rnn_model.add(SimpleRNN(32))
    my_rnn_model.add(Dense(2)) # The time step of the output

    my_rnn_model.compile(optimizer='rmsprop', loss='mean_squared_error')

    # fit the RNN model
    my_rnn_model.fit(X_train, y_train, epochs=100, batch_size=150, verbose=0)

    # Finalizing predictions
    rnn_predictions = my_rnn_model.predict(X_test)
    from sklearn.preprocessing import MinMaxScaler
    rnn_predictions = sc.inverse_transform(rnn_predictions)

    return my_rnn_model, rnn_predictions


X_train, y_train, X_test, sc = ts_train_test_normalize(all_data,5,2)
my_rnn_model, rnn_predictions_2 = simple_rnn_model(X_train, y_train, X_test, sc)
rnn_predictions_2[1:10]
# Out:
# 23/23 [==============================] - 0s 3ms/step
# array([[91.48816 , 91.972244],
#        [91.15453 , 92.27577 ],
#        [91.30369 , 92.05489 ],
#        [91.55034 , 92.34173 ],
#        [91.78309 , 92.893814],
#        [91.54069 , 92.36506 ],
#        [91.5086  , 92.548584],
#        [91.71192 , 92.61035 ],
#        [90.94309 , 91.9897  ]], dtype=float32)

# %%
def LSTM_model(X_train, y_train, X_test, sc):
    # create a model
    from keras.models import Sequential
    from keras.layers import Dense, SimpleRNN, GRU, LSTM
    from tensorflow.keras.optimizers import SGD
    
    # The LSTM architecture
    my_LSTM_model = Sequential()
    my_LSTM_model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
    my_LSTM_model.add(LSTM(units=50, activation='tanh'))
    my_LSTM_model.add(Dense(units=2))

    # Compiling
    my_LSTM_model.compile(optimizer=SGD(lr=0.02, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
    # Fitting to the training set
    my_LSTM_model.fit(X_train,y_train,epochs=100,batch_size=150, verbose=0)

    LSTM_prediction = my_LSTM_model.predict(X_test)
    LSTM_prediction = sc.inverse_transform(LSTM_prediction)

    return my_LSTM_model, LSTM_prediction

my_LSTM_model, LSTM_prediction = LSTM_model(X_train, y_train, X_test, sc)
LSTM_prediction[1:10]
# Out:
# C:\Users\saivi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 23/23 [==============================] - 2s 6ms/step
# array([[92.66427 , 92.607834],
#        [92.71214 , 92.66997 ],
#        [92.89803 , 92.87773 ],
#        [93.44847 , 93.42075 ],
#        [93.98082 , 93.92171 ],
#        [93.98728 , 93.93415 ],
#        [94.18026 , 94.10126 ],
#        [94.05926 , 93.980125],
#        [93.7826  , 93.70372 ]], dtype=float32)

# %%
def GRU_model(X_train, y_train, X_test, sc):
    # create a model
    from keras.models import Sequential
    from keras.layers import Dense, SimpleRNN, GRU
    from tensorflow.keras.optimizers import SGD
    
    # The GRU architecture
    my_GRU_model = Sequential()
    # First GRU layer with Dropout regularisation
    my_GRU_model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
    #my_GRU_model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
    #my_GRU_model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
    my_GRU_model.add(GRU(units=50, activation='tanh'))
    my_GRU_model.add(Dense(units=2))

    # Compiling the RNN
    my_GRU_model.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
    # Fitting to the training set
    my_GRU_model.fit(X_train,y_train,epochs=100,batch_size=150, verbose=0)

    GRU_prediction = my_GRU_model.predict(X_test)
    GRU_prediction = sc.inverse_transform(GRU_prediction)

    return my_GRU_model, GRU_prediction

my_GRU_model, GRU_prediction = GRU_model(X_train, y_train, X_test, sc)
GRU_prediction[1:10]
# Out:
# C:\Users\saivi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 23/23 [==============================] - 1s 3ms/step
# array([[92.96178 , 93.00575 ],
#        [93.156425, 93.19805 ],
#        [93.566795, 93.608025],
#        [94.10654 , 94.14945 ],
#        [94.38873 , 94.43381 ],
#        [94.4351  , 94.48065 ],
#        [94.393074, 94.44027 ],
#        [94.26522 , 94.31234 ],
#        [93.93556 , 93.98208 ]], dtype=float32)

# %%
actual_pred_plot(LSTM_prediction)
# Out:
# (420.3801, <AxesSubplot:xlabel='Date'>)

# %%
actual_pred_plot(rnn_predictions_2)
# Out:
# (648.62494, <AxesSubplot:xlabel='Date'>)

# %%
actual_pred_plot(GRU_prediction)
# Out:
# (126.16588, <AxesSubplot:xlabel='Date'>)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, GRU
from tensorflow.keras.optimizers import SGD

# %%
# The GRU architecture
my_GRU_model = Sequential()
# First GRU layer with Dropout regularisation
my_GRU_model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
my_GRU_model.add(GRU(units=50, activation='tanh'))
my_GRU_model.add(Dense(units=2))

# Compiling the RNN
my_GRU_model.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
# Out:
# C:\Users\saivi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%